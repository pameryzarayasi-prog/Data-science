# %%
edad=30
if edad >=18:
   print("soy mayor de edad")
elif edad >= 13:
   print("soy un adolecente")
else:
   print("soy un infante")
# Out:
# soy mayor de edad

# %%
if edad >=18:
   print("soy mayor de edad")
if edad >= 13:
   print("soy un adolecente")
else:
   print("soy un infante")
# Out:
# soy mayor de edad
# soy un adolecente

# %%
temperatura= 14

alerta1=15
if temperatura> alerta1:
    print("peligro")
elif temperatura>10 and temperatura<20:
    print("condicion normal")
# Out:
# condicion normal

# %%
A=input("Elige un némero: ")
A1=int(A)

if A1>0:
    print("El número es positivo")
elif A1 == 0:
    print("El numero es cero")
else:
    print("El numero es negativo")
# Out:
# El número es positivo

# %%
if A1>18:
    print("Puede votar")
else:
    print("No puede votar")
# Out:
# No puede votar
