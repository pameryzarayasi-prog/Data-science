# %%
A= 30
B= 2
print(A / B)
print(A + B)
print(A-B)
print(A // B)
print(A * B)
# Out:
# 15.0
# 32
# 28
# 15
# 60

# %%
C= 10
D= 4
E= 12

print(C == 4)
print(C != D)
print(D >= C)
# Out:
# False
# True
# False
