# %%
### remove
## pop remueve el ultimo elemento de la lista
# sorted ordena elementos sprted (lista, reverse=false)
# len (lista )
# append inserta un elemento al final de la lista
insert inserta un elemento en la posicion publish_display_data

# %%
list(range(7))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
lista_1= [0, 1, 2, 3, 4]

lista_1.insert(-1,6)

# %%
lista_1= [0, 1, 2, 3, 4]
lista_2= [9,8,7]



for item in lista_1:
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lista_5= [0,1,2,3,6]

lista_5.insert(-1,7)

# %%
lista_5= [0,1,2,3,6]

lista_5.insert(-1,7)

# %%
lista_5= [2,3,6]

lista_5.insert(-1, 7)
print(lista_5)
# Out:
# [2, 3, 7, 6]

# %%
lista_5.remove(3)
print(lista_5)
# Out:
# [2, 7, 6]
