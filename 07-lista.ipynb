# %%
### remove
## pop remueve el ultimo elemento de la lista
# sorted ordena elementos sprted (lista, reverse=false)
# len (lista )
# append inserta un elemento al final de la lista
insert inserta un elemento en la posicion publish_display_data

# %%
list(range(7))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
numeros_impare=[1, 3, 5, 7]
len(numeros_impare)
# Out:
# 4

# %%
lista_1= [0, 1, 2, 3, 4]

lista_1.insert(-1,6)

# %%
lista_1= [0, 1, 2, 3, 4]
lista_2= [9,8,7]



for item in lista_1:
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lista_5= [0,1,2,3,6]

lista_5.insert(-1,7)

# %%
lista_5= [0,1,2,3,6]

lista_5.insert(-1,7)

# %%
lista_5= [2,3,6]

lista_5.insert(-1, 7)
print(lista_5)
# Out:
# [2, 3, 7, 6]

# %%
lista_5.remove(3)
print(lista_5)
# Out:
# [2, 7, 6]

# %%
numeros_impare.append(13)
print(numeros_impare)
# Out:
# [1, 3, 5, 7, 13]

# %%
import random
numero_random=[]

for _ in range(10):
    numero_random.append(random.randint(0, 20))

    print(numero_random)
# Out:
# [10]
# [10, 16]
# [10, 16, 10]
# [10, 16, 10, 4]
# [10, 16, 10, 4, 5]
# [10, 16, 10, 4, 5, 8]
# [10, 16, 10, 4, 5, 8, 19]
# [10, 16, 10, 4, 5, 8, 19, 15]
# [10, 16, 10, 4, 5, 8, 19, 15, 6]
# [10, 16, 10, 4, 5, 8, 19, 15, 6, 13]

# %%
sorted(numero_random, reverse=True)
# Out:
# [19, 16, 15, 13, 10, 10, 8, 6, 5, 4]

# %%
numeros_impare.clear()

# %%
numero_random.reverse()
print(numero_random)
# Out:
# [13, 6, 15, 19, 8, 5, 4, 10, 16, 10]

# %%
numero_random.append(13)
print(numero_random)
# Out:
# [13, 6, 15, 19, 8, 5, 4, 10, 16, 10, 13, 13]

# %%
numero_random.count(13)
# Out:
# 3

# %%
count=0
for letra in numero_random:
 if letra == 13:
  count += 1

print(count)
# Out:
# 3
