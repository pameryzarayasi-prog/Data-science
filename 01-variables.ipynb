# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print("hola como estas")
# Out:
# hola como estas

# %%
A = "pamery"

print(len(A))
# Out:
# 6

# %%
nombre = "Pamery"
apellido = "Zarayasi"
print(nombre + ' ' + apellido)
edad = 22


print("mi edade dentro de 39 años: ", edad + 39)
# Out:
# Pamery Zarayasi
# mi edade dentro de 39 años:  61
